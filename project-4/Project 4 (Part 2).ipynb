# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
import regex as re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
df = pd.read_csv('final_df')
df.reset_index(drop=True, inplace=True)
df.drop(columns=['Unnamed: 0'], inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2104 entries, 0 to 2103
# Data columns (total 6 columns):
# job_category        2104 non-null object
# job_title           2104 non-null object
# company_name        2104 non-null object
# location            2078 non-null object
# summary             2104 non-null object
# salary_high_tier    2104 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 98.7+ KB

# %%
df
# Out:
#           job_category                                          job_title  \
# 0       data_scientist                                     data scientist
# 1       data_scientist                                     data scientist
# 2       data_scientist  growth strategy  operations strategic planning...
# 3       data_scientist                                     data scientist
# 4       data_scientist                  data scientists  machine learning
# 5       data_scientist  data scientist  aml group customer analytics  ...
# 6       data_scientist                         data engineer data science
# 7       data_scientist                                     data scientist
# 8       data_scientist                                     data scientist
# 9       data_scientist                                     data scientist
# 10      data_scientist                                     data scientist
# 11      data_scientist                                     data scientist
# 12      data_scientist                data scientist bank central up to k
# 13      data_scientist             data science lead large customer sales
# 14      data_scientist       data scientist global data innovation centre
# 15      data_scientist                                     data scientist
# 16      data_scientist                        data science senior manager
# 17      data_scientist                                     data scientist
# 18      data_scientist                            embedded data scientist
# 19      data_scientist                                     data scientist
# 20      data_scientist                                     data scientist
# 21      data_scientist                                     data scientist
# 22      data_scientist                              junior data scientist
# 23      data_scientist                                     data scientist
# 24      data_scientist                       data scientist  data science
# 25      data_scientist                                     data scientist
# 26      data_scientist                              data scientist junior
# 27      data_scientist                                 data scientistdeja
# 28      data_scientist  head of data analytics strategic technology ce...
# 29      data_scientist                   associate  senior data scientist
# ...                ...                                                ...
# 2074  business_analyst                                data analytics lead
# 2075  business_analyst           kfinancebusiness analystmnctai seng days
# 2076  business_analyst     finance analyst retail mnc tampines perm up to
# 2077      data_analyst                                       data analyst
# 2078      data_analyst                    reports analyst  data migration
# 2079      data_analyst                                       data analyst
# 2080      data_analyst                                       data analyst
# 2081      data_analyst                                     market analyst
# 2082      data_analyst                                      fraud analyst
# 2083      data_analyst                                     system analyst
# 2084      data_analyst             client strategy and consulting analyst
# 2085      data_analyst                                it business analyst
# 2086      data_analyst                           business systems analyst
# 2087      data_analyst                         technical business analyst
# 2088      data_analyst                            analyst credit research
# 2089      data_analyst            research analyst healthcareoffice hours
# 2090      data_analyst                regional financial planner  analyst
# 2091      data_analyst      business analyst degsharepointnovenaurgentkjc
# 2092      data_analyst                            business system analyst
# 2093      data_analyst                                     msbi developer
# 2094      data_analyst                                 digital strategist
# 2095      data_analyst                                sap abap consultant
# 2096      data_analyst                                 investment analyst
# 2097      data_analyst                                 software developer
# 2098      data_analyst                          it recruitment consultant
# 2099      data_analyst              crm executive automotive data analyst
# 2100      data_analyst                  test analyst  banking domain  mnc
# 2101      data_analyst                                     system analyst
# 2102      data_analyst                  information security risk analyst
# 2103      data_analyst                                it database analyst
#
#                                            company_name           location  \
# 0                                                indeed                NaN
# 1                                      capita singapore                NaN
# 2                                                wework                NaN
# 3                                gateway search pte ltd                NaN
# 4                                  biofourmis singapore          singapore
# 5                                             ocbc bank          singapore
# 6                                               twitter          singapore
# 7                                                zyllem          singapore
# 8                                             lenddoefl          singapore
# 9                                cxa group pte. limited          singapore
# 10                                                basis          singapore
# 11                           pan-united corporation ltd                NaN
# 12                             kelly services singapore                NaN
# 13                                               google          singapore
# 14                                         dentsu aegis          singapore
# 15                                        cisco careers          singapore
# 16                                                 dell  central singapore
# 17                                                 dell  central singapore
# 18                                           biofourmis          singapore
# 19           ntuc enterprise nexus co-operative limited          singapore
# 20                                      validus capital            raffles
# 21                                     xcellink pte ltd          singapore
# 22                                           transferto          singapore
# 23                                       axinan pte ltd          singapore
# 24                          helius technologies pte ltd          singapore
# 25                           hewlett packard enterprise          singapore
# 26                                           itcs group          singapore
# 27                                                mozat          singapore
# 28               singapore technologies engineering ltd          singapore
# 29                                        ncs pte. ltd.          singapore
# ...                                                 ...                ...
# 2074  global artificial intelligence consulting company  central singapore
# 2075                               search index pte ltd          singapore
# 2076                                             ksc hr          singapore
# 2077                    ic pro og technologies pte. ltd          singapore
# 2078                                         rumbleasia          singapore
# 2079                                      ecnet limited          singapore
# 2080                                            tvconal          singapore
# 2081          phillips 66 international trading pte ltd          singapore
# 2082                      aspire financial technologies          singapore
# 2083                                    vision manpower          singapore
# 2084                                               cbre          singapore
# 2085                                      ecnet limited          singapore
# 2086                         techsource systems pte ltd                ubi
# 2087                                         rumbleasia          singapore
# 2088                                    fintrux network          singapore
# 2089                                aim recruit pte ltd          singapore
# 2090                ninja logistics pte ltd (ninja van)          singapore
# 2091                           people profilers pte ltd          singapore
# 2092                                               cbre          singapore
# 2093                                  percept solutions          singapore
# 2094              reveres management associates pte ltd          singapore
# 2095                        dezire technologies pte ltd          singapore
# 2096                     just recruit singapore pte ltd          singapore
# 2097                                            tvconal          singapore
# 2098                                  percept solutions          singapore
# 2099                                bizhub asia pte ltd  central singapore
# 2100                                       apba pte ltd          singapore
# 2101                       dow technologies and systems          singapore
# 2102                        spe networks - asia pte ltd          singapore
# 2103                                atomrecruit pte ltd          singapore
#
#                                                 summary  salary_high_tier
# 0     significant prior success as a data scientist ...                 1
# 1     data scientist   data scientist needed to impr...                 1
# 2     ensuring data quality minimum  years of experi...                 0
# 3     assess the effectiveness and accuracy of new d...                 1
# 4     knowledge in big data technologies including c...                 0
# 5     data scientist  aml group customer analytics  ...                 1
# 6     data engineers work alongside data scientists ...                 0
# 7     interpreting data analyzing results using stat...                 1
# 8     proven experience in data manipulation as a da...                 1
# 9     leverage data visualization techniques and too...                 1
# 10    experience with etl and implementing efficient...                 1
# 11    design and qualifying processes for gathering ...                 0
# 12    interested candidates kindly submit your updat...                 1
# 13    as a data science lead you will generate actio...                 0
# 14    data scientist global data innovation centre a...                 0
# 15    as a data scientist you will experience with d...                 1
# 16    sql data modeling data warehousing concept  sd...                 1
# 17    we cant wait for you to discover this for your...                 1
# 18    responsibilities  develop and implement embedd...                 1
# 19    you will be proficient in the application of a...                 0
# 20    work with data sets residing in different data...                 0
# 21    experience with data processing and data analy...                 1
# 22    the data science  data engineering department ...                 0
# 23    work with backend engineers to architect data ...                 0
# 24    experience as data scientist working on variou...                 0
# 25    we have an exciting opportunity for a data sci...                 1
# 26    strong interest in data science scope and buil...                 0
# 27    years experience as a statisticianmachine lear...                 0
# 28    heshe shall develop a team of data practitione...                 1
# 29    experience working with very large data sets i...                 1
# ...                                                 ...               ...
# 2074  design and execute advanced business analytics...                 1
# 2075  business intelligence analyst support the inte...                 1
# 2076  ensures asia fisher business unit management r...                 1
# 2077  data analyst for analytical solutions work wit...                 1
# 2078  data analyst  reporting analyst data migration...                 1
# 2079  looking for data analyst sql and tableau skill...                 0
# 2080  the data analyst role will be a technical role...                 0
# 2081  analyze fundamental data provide ad hoc analys...                 1
# 2082  perform data analysis and provide to risk anal...                 0
# 2083  develop program to capture machine data to lin...                 0
# 2084  ability to comprehend analyze and interpret da...                 0
# 2085  coordinate integration related conversation an...                 1
# 2086  provide business insights utilizing data from ...                 0
# 2087  familiar with data messaging  formats  years e...                 1
# 2088  identify relevant data sources and vendors for...                 0
# 2089  possess good organization management with data...                 0
# 2090  financial planning  analyst excellent analytic...                 0
# 2091  managing data model within bi platform working...                 0
# 2092  collects data and runs basic reports in respon...                 1
# 2093  experience in data warehouses modeling using s...                 0
# 2094  media buyer  analyst comfortable speaking abou...                 0
# 2095  abap core data services abap cds view sap abap...                 1
# 2096  the investment analyst will be responsible for...                 1
# 2097  build infrastructure to scale up data ingest a...                 0
# 2098  recruitment experience in it hardware software...                 0
# 2099  responsibilities  assist the team in leads man...                 0
# 2100  prepare test data update test case and require...                 0
# 2101  load scripting to process data from operationa...                 0
# 2102  support regulatory compliance with pci dss pay...                 1
# 2103  perform database documentation including data ...                 1
#
# [2104 rows x 6 columns]

# %%
data_jobs = df[df.job_title.str.contains('data')]
non_data_jobs = df[~df.job_title.str.contains('data')]
data_jobs.shape
# Out:
# (667, 6)

# %%
ana_jobs = non_data_jobs[non_data_jobs.job_title.str.contains('analyst')]
non_ana_jobs = non_data_jobs[~non_data_jobs.job_title.str.contains('analyst')]
ana_jobs.shape
# Out:
# (1109, 6)

# %%
eng_jobs = non_ana_jobs[(non_ana_jobs.job_title.str.contains('engineer')) | (non_ana_jobs.job_title.str.contains('database'))]
non_eng_jobs = non_ana_jobs[(~non_ana_jobs.job_title.str.contains('engineer')) & (~non_ana_jobs.job_title.str.contains('database'))]
eng_jobs.shape
# Out:
# (54, 6)

# %%
man_jobs = non_eng_jobs[non_eng_jobs.job_title.str.contains('manager')]
non_man_jobs = non_eng_jobs[~non_eng_jobs.job_title.str.contains('manager')]
man_jobs.shape
# Out:
# (38, 6)

# %%
df_title = pd.DataFrame()
data_jobs.job_title = data_jobs.job_title.map(lambda x: 'data_jobs')
ana_jobs.job_title = ana_jobs.job_title.map(lambda x: 'analyst_jobs')
eng_jobs.job_title = eng_jobs.job_title.map(lambda x: 'engineer_jobs')
man_jobs.job_title = man_jobs.job_title.map(lambda x: 'manager_jobs')
non_man_jobs.job_title = non_man_jobs.job_title.map(lambda x: 'other_jobs')

# %%
df_title['job_titles'] = pd.concat([data_jobs.job_title,ana_jobs.job_title,
                        eng_jobs.job_title,man_jobs.job_title,
                        non_man_jobs.job_title], ignore_index=True)

# %%
final_df = pd.concat([df[['company_name','summary','salary_high_tier']], df_title.job_titles], axis=1)

# %%
# convert job_title into numbers
final_df.job_titles = final_df.job_titles.map(lambda x: 1 if x == 'data_jobs' else
                                             2 if x == 'analyst_jobs' else
                                             3 if x == 'engineer_jobs' else
                                             4 if x == 'manager_jobs' else 5)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2104 entries, 0 to 2103
# Data columns (total 4 columns):
# company_name        2104 non-null object
# summary             2104 non-null object
# salary_high_tier    2104 non-null int64
# job_titles          2104 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 65.8+ KB

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, cross_val_predict, GridSearchCV
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# %%
# Get TFIDF for company name
job_company_tvec = TfidfVectorizer(ngram_range=(1,3), stop_words='english', min_df=2, max_df=0.5, max_features=25)
job_company_tvec.fit(final_df.company_name)
job_company_tvec_df = pd.DataFrame(job_company_tvec.transform(final_df.company_name).todense(),
                       columns=['company_[' + f + ']' for f in job_company_tvec.get_feature_names()])

# %%
# Get TFIDF for job summary
job_summary_tvec = TfidfVectorizer(ngram_range=(1,3), stop_words='english', min_df=2, max_df=0.5, max_features=25)
job_summary_tvec.fit(final_df.summary)
job_summary_tvec_df = pd.DataFrame(job_summary_tvec.transform(final_df.summary).todense(),
                       columns=['summary_[' + f + ']' for f in job_summary_tvec.get_feature_names()])

# %%
X = pd.concat([final_df[['salary_high_tier']], job_company_tvec_df, job_summary_tvec_df], axis=1)
y = final_df['job_titles'].values.ravel()

# %%
# Get training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Standardize predictors
X_train_ss = StandardScaler().fit_transform(X_train)
X_test_ss = StandardScaler().fit_transform(X_test)

# %%
X_train_ss = pd.DataFrame(X_train_ss, columns=X_train.columns)
X_test_ss = pd.DataFrame(X_test_ss, columns=X_train.columns)

# %%
# Gridsearch for Ridge and Lasso Logistic Regression, optimize C
parameters = {
    'penalty':['l1','l2'],
    'solver':['liblinear'],
    'C':np.logspace(-5,0,100)
}

print ("GRID SEARCH:")
lr_grid_search = GridSearchCV(LogisticRegression(), parameters, cv=10, verbose=0)
lr_grid_search.fit(X_train_ss, y_train)
print ("Best parameters set:")
lr_best_parameters = lr_grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print ("\t%s: %r" % (param_name, lr_best_parameters[param_name]))
# Out:
# GRID SEARCH:
# Best parameters set:
# 	C: 0.0774263682681127
# 	penalty: 'l1'
# 	solver: 'liblinear'

# %%
print ("Logistic Regression with best parameter:")
clf = LogisticRegression(**lr_best_parameters)
clf.fit(X_train_ss, y_train)
lr_gs_pred = clf.predict(X_test_ss)
print(metrics.classification_report(y_test, lr_gs_pred, labels=[1,2,3,4,5],
                                    target_names=['data jobs','analyst jobs','engineer jobs','manager jobs','other jobs']))
# Out:
# Logistic Regression with best parameter:
#                precision    recall  f1-score   support
#
#     data jobs       0.71      0.22      0.33       219
#  analyst jobs       0.54      0.96      0.69       318
# engineer jobs       0.00      0.00      0.00        17
#  manager jobs       0.00      0.00      0.00         8
#    other jobs       0.00      0.00      0.00        70
#
#   avg / total       0.52      0.56      0.46       632
# C:\Users\ayden\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# gridsearch params
dtc_params = {
    'max_depth':[None,1,2,3,4],
    'max_features':[None,'log2','sqrt',2,3,4,5],
    'min_samples_split':[2,3,4,5,10,15,20,25,30,40,50]
}

# set the gridsearch
dtc_gs = GridSearchCV(DecisionTreeClassifier(), dtc_params, cv=5, verbose=1)

# %%
# use the gridsearch C model to fit the data
dtc_gs.fit(X_train_ss, y_train)
# Out:
# Fitting 5 folds for each of 385 candidates, totalling 1925 fits
# [Parallel(n_jobs=1)]: Done 1925 out of 1925 | elapsed:   11.7s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': [None, 1, 2, 3, 4], 'max_features': [None, 'log2', 'sqrt', 2, 3, 4, 5], 'min_samples_split': [2, 3, 4, 5, 10, 15, 20, 25, 30, 40, 50]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
# Best Estimator
dtc_best = dtc_gs.best_estimator_
print(dtc_gs.best_params_)
print(dtc_gs.best_score_)
# Out:
# {'max_depth': 4, 'max_features': None, 'min_samples_split': 10}
# 0.5998641304347826

# %%
pred = dtc_best.predict(X_test_ss)
print(metrics.classification_report(y_test, pred, labels=[1,2,3,4,5], target_names=['data jobs','analyst jobs','engineer jobs','manager jobs','other jobs']))
# Out:
#                precision    recall  f1-score   support
#
#     data jobs       0.68      0.22      0.34       219
#  analyst jobs       0.54      0.95      0.69       318
# engineer jobs       0.00      0.00      0.00        17
#  manager jobs       0.00      0.00      0.00         8
#    other jobs       1.00      0.03      0.06        70
#
#   avg / total       0.62      0.56      0.47       632
# C:\Users\ayden\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
fi = pd.DataFrame({
        'feature':X_train_ss.columns,
        'importance':dtc_best.feature_importances_
    })

fi.sort_values('importance', ascending=False, inplace=True)
fi.head(10)
# Out:
#                      feature  importance
# 44       summary_[scientist]    0.543288
# 27         summary_[analyst]    0.127383
# 43         summary_[science]    0.126711
# 33  summary_[data analytics]    0.065149
# 24    company_[technologies]    0.052376
# 35      summary_[experience]    0.036833
# 29        summary_[business]    0.020528
# 41    summary_[requirements]    0.018492
# 32    summary_[data analyst]    0.009241
# 36       summary_[financial]    0.000000

# %%
coef = lr_grid_search.best_estimator_.coef_

lr_coef_data = pd.DataFrame({'coef':coef[0],
                    'mag':np.abs(coef[0]),
                    'pred':X_test.columns})

lr_coef_analyst = pd.DataFrame({'coef':coef[1],
                    'mag':np.abs(coef[1]),
                    'pred':X_test.columns})

lr_coef_engineer = pd.DataFrame({'coef':coef[2],
                    'mag':np.abs(coef[2]),
                    'pred':X_test.columns})

lr_coef_manager = pd.DataFrame({'coef':coef[3],
                    'mag':np.abs(coef[3]),
                    'pred':X_test.columns})

lr_coef_other = pd.DataFrame({'coef':coef[4],
                    'mag':np.abs(coef[4]),
                    'pred':X_test.columns})

lr_coef_data.sort_values('mag', ascending=False, inplace=True)
lr_coef_analyst.sort_values('mag', ascending=False, inplace=True)
lr_coef_engineer.sort_values('mag', ascending=False, inplace=True)
lr_coef_manager.sort_values('mag', ascending=False, inplace=True)
lr_coef_other.sort_values('mag', ascending=False, inplace=True)

# %%
# Top predictors for data jobs
lr_coef_data.head(10)
# Out:
#         coef       mag                      pred
# 44  0.710262  0.710262       summary_[scientist]
# 27 -0.385630  0.385630         summary_[analyst]
# 43  0.264716  0.264716         summary_[science]
# 29  0.199496  0.199496        summary_[business]
# 9  -0.157887  0.157887          company_[google]
# 33  0.155794  0.155794  summary_[data analytics]
# 39 -0.121689  0.121689      summary_[management]
# 46 -0.073316  0.073316         summary_[systems]
# 37 -0.064041  0.064041        summary_[insights]
# 19  0.057494  0.057494       company_[singapore]

# %%
# Top predictors for analyst jobs
lr_coef_analyst.head(10)
# Out:
#         coef       mag                      pred
# 44 -0.665745  0.665745       summary_[scientist]
# 27  0.179863  0.179863         summary_[analyst]
# 43 -0.178767  0.178767         summary_[science]
# 9   0.075656  0.075656          company_[google]
# 37  0.070916  0.070916        summary_[insights]
# 31  0.053440  0.053440   summary_[data analysis]
# 39  0.049047  0.049047      summary_[management]
# 16 -0.044687  0.044687             company_[pte]
# 33 -0.044463  0.044463  summary_[data analytics]
# 47 -0.041786  0.041786            summary_[team]

# %%
# Top predictors for engineer jobs
lr_coef_engineer.head(10)
# Out:
#     coef  mag                        pred
# 0    0.0  0.0            salary_high_tier
# 38   0.0  0.0           summary_[looking]
# 28   0.0  0.0         summary_[analytics]
# 29   0.0  0.0          summary_[business]
# 30   0.0  0.0  summary_[business analyst]
# 31   0.0  0.0     summary_[data analysis]
# 32   0.0  0.0      summary_[data analyst]
# 33   0.0  0.0    summary_[data analytics]
# 34   0.0  0.0    summary_[data scientist]
# 35   0.0  0.0        summary_[experience]

# %%
# Top predictors for manager jobs
lr_coef_manager.head(10)
# Out:
#         coef       mag                        pred
# 4   0.199950  0.199950              company_[bank]
# 38  0.052768  0.052768           summary_[looking]
# 9   0.017682  0.017682            company_[google]
# 2   0.007842  0.007842              company_[asia]
# 0   0.000000  0.000000            salary_high_tier
# 39  0.000000  0.000000        summary_[management]
# 29  0.000000  0.000000          summary_[business]
# 30  0.000000  0.000000  summary_[business analyst]
# 31  0.000000  0.000000     summary_[data analysis]
# 32  0.000000  0.000000      summary_[data analyst]

# %%
# Top predictors for other jobs
lr_coef_other.head(10)
# Out:
#         coef       mag                        pred
# 29 -0.188175  0.188175          summary_[business]
# 32  0.139338  0.139338      summary_[data analyst]
# 16  0.138465  0.138465               company_[pte]
# 14  0.108968  0.108968           company_[limited]
# 33 -0.090046  0.090046    summary_[data analytics]
# 24  0.085544  0.085544      company_[technologies]
# 30  0.085246  0.085246  summary_[business analyst]
# 44 -0.081667  0.081667         summary_[scientist]
# 1   0.078941  0.078941          company_[ambition]
# 42 -0.067197  0.067197          summary_[research]

# %%
# That's all I can muster up, I feel very inadequate hahaha, not enough competency to do this within the time. :(
